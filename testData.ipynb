# %%
import pandas as pd
df = pd.read_csv('league_matches_data_final_NA.csv')

df.head()
# Out:
#          match_id winner  blue_champion_0  blue_mastery_0  blue_champion_1  \
# 0  NA1_5155793891   blue              122          136183              517
# 1  NA1_5155755771    red              893           40350               76
# 2  NA1_5155721452   blue               43           14177               76
# 3  NA1_5155672191    red              799            7841               59
# 4  NA1_5155651145    red              164          143046               76
#
#    blue_mastery_1  blue_champion_2  blue_mastery_2  blue_champion_3  \
# 0           26970              910           58733               42
# 1           95470              777           41644               42
# 2            8313               81            3162               80
# 3           57839              711          685186              910
# 4           27540              950         1082191               63
#
#    blue_mastery_3  ...  red_champion_0  red_mastery_0  red_champion_1  \
# ...

# %%
len(df['match_id'])
# Out:
# 25000

# %%
df = df.drop_duplicates(subset='match_id')
len(df['match_id'].unique())
# Out:
# 12622
